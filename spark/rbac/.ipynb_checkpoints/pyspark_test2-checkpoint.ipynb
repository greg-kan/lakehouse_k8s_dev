# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("SparkK8sTest") \
    .getOrCreate()
# Out:
# 26/02/22 22:11:08 WARN Utils: Your hostname, ls02 resolves to a loopback address: 127.0.1.1; using 192.168.1.6 instead (on interface wlp5s0)
# 26/02/22 22:11:08 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 26/02/22 22:11:09 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df = spark.range(1, 1000000)
df.count()
# Out:
# 999999
# 26/02/22 22:11:29 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
spark.stop()
# Out:
# 26/02/22 22:12:09 WARN ExecutorPodsWatchSnapshotSource: Kubernetes client has been closed.
